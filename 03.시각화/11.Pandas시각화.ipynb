# %% [markdown]
# # Pandas 시각화

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
mpl.rcParams['axes.unicode_minus'] = False
mpl.rcParams['font.family'] = 'Malgun Gothic'

# %% [markdown]
# ### 1.Line graph

# %%
np.random.seed(2022)
df = pd.DataFrame(np.random.randn(100,3),
                  index = pd.date_range('2022-1-1', periods=100),
                  columns= ['A','B','C']).cumsum()
df.head()
# Out:
#                    A         B         C
# 2022-01-01 -0.000528 -0.274901 -0.139286
# 2022-01-02  1.984158  0.007208  0.621523
# 2022-01-03  2.285140  0.547505  0.995020
# 2022-01-04  2.662953  0.457292 -1.310923
# 2022-01-05  3.805713 -1.078362 -2.174675

# %%
df.plot()
plt.title('Pandas 의 plot method 의 사용 예')
plt.xlabel('일자') , plt.ylabel('데이터')
plt.show()

# %%
iris = sns.load_dataset('iris')

plt.figure(figsize=(12,6))
iris.sepal_length[:50].plot(kind='bar', rot=45)
plt.title('setosa 품종의 sepal length')
plt.show()

# %%
df2.columns.name= 'Feature'
df2.plot.bar(rot=0)
plt.title('iris 각 품종의 feathur 별 평균')
plt.ylim(0.9)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2464/1066504726.py in <module>
# ----> 1 df2.columns.name= 'Feature'
#       2 df2.plot.bar(rot=0)
#       3 plt.title('iris 각 품종의 feathur 별 평균')
#       4 plt.ylim(0.9)
#       5 plt.show()
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ### 3. pie chart

# %%
titanic = sns.load_dataset('titanic')
s = titanic['class'].value_counts()
s
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
s.plot.pie(autopct='%.1ff%%')
plt.title('선실별 승객수',color='w')
plt.show()

# %%
iris.boxplot(by='species', figsize=(10,8))
plt.show()
