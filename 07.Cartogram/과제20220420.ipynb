# %% [markdown]
# <pre>
# 경찰 민원포탈 > 경찰관서 찾기 > 목록에서 찾기 > 서울
# 에서 서울 소재 31개의 경찰서의 이름과 주소를 크롤링하여 데이터프레임을 만드세요. (40점)
# (단, 셀레니움을 이용해서 가져오지 않고 다른 사이트를 이용해서 가져오면 감점 20점)
# </pre>

# %%
import numpy as np
import requests, re
import pandas as pd
from tqdm.notebook import tqdm
from wordcloud import WordCloud
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus']= False
mpl.rcParams['font.family'] = 'Malgun Gothic'
from bs4 import BeautifulSoup
from selenium import webdriver
import time
from tqdm.notebook import tqdm
from urllib.parse import quote
from selenium.webdriver.common.keys import Keys
import requests
import json

# %%
Chromedriver = '../05.Crawling/chromedriver.exe'
#driver = webdriver.Chrome(chromedriver)

# %%
url = 'https://minwon.police.go.kr/#customerCenter/plcstSearch'
driver = webdriver.Chrome(Chromedriver)
driver.get(url)

# %%
driver.find_element_by_css_selector('#tab3_1').click()
driver.find_element_by_css_selector('#indexedA').click()

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
trs = soup.select('#minwonTbody > tr')
len(trs)
# Out:
# 5

# %%
# 경찰서 명
tr = trs[0]
tr.select_one('tr > td').get_text().split()[-1]
# Out:
# '서울은평경찰서'

# %%
# 경찰서 주소
tr.select_one('td.title').get_text().strip()
# Out:
# '서울특별시 중구 수표로 27'

# %%
ps_name = tr.select_one('td').get_text().strip()
ps_addr = tr.select_one('td.title').get_text().strip()
ps_name , ps_addr
# Out:
# ('경찰청 서울특별시경찰청 서울중부경찰서', '서울특별시 중구 수표로 27')

# %%
lines =[]
for tr in trs:
    ps_name = tr.select_one('td').get_text().strip()
    ps_addr = tr.select_one('td.title').get_text().strip()
    lines.append([ps_name, ps_addr])
lines
# Out:
# [['경찰청 서울특별시경찰청 서울중부경찰서', '서울특별시 중구 수표로 27'],
#  ['경찰청 서울특별시경찰청 서울종로경찰서', '서울특별시 종로구 율곡로 46'],
#  ['경찰청 서울특별시경찰청 서울남대문경찰서', '서울특별시 중구 한강대로 410'],
#  ['경찰청 서울특별시경찰청 서울서대문경찰서', '서울특별시 서대문구 통일로 113'],
#  ['경찰청 서울특별시경찰청 서울혜화경찰서', '서울특별시 종로구 창경궁로 112-16']]

# %%
driver.find_element_by_css_selector('a:nth-child(5)').click()

# %%
for i in range(2,9):
    test = '//*[@id="pagination"]/div/a[{}]'.format(i)
    driver.find_element_by_xpath(test).click()
    time.sleep(2)

# %% [markdown]
# - 컴퓨터 속도 때문에 중간중간 time.sleep를 많이 사용하였습니다

# %%
lines =[]
url = 'https://minwon.police.go.kr/#customerCenter/plcstSearch'
driver = webdriver.Chrome(Chromedriver)
driver.get(url)
time.sleep(2)
driver.find_element_by_css_selector('#tab3_1').click()
time.sleep(2)
driver.find_element_by_css_selector('#indexedA').click()
time.sleep(2)

for page in range(2,9):
    xpath = '//*[@id="pagination"]/div/a[{}]'.format(page)
    driver.find_element_by_xpath(xpath).click()
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    trs = soup.select('#minwonTbody > tr')
    for tr in trs:
        ps_name = tr.select_one('td').get_text().strip().split()[-1]
        ps_addr = tr.select_one('td.title').get_text().strip()
        lines.append([ps_name, ps_addr])
        time.sleep(2)
driver.close()

# %%
len(lines)
# Out:
# 31

# %%
df1= pd.DataFrame(lines, columns=['경찰서명','주소'])
df1
# Out:
#         경찰서명                                  주소
# 0    서울중부경찰서                     서울특별시 중구 수표로 27
# 1    서울종로경찰서                    서울특별시 종로구 율곡로 46
# 2   서울남대문경찰서                   서울특별시 중구 한강대로 410
# 3   서울서대문경찰서                  서울특별시 서대문구 통일로 113
# 4    서울혜화경찰서               서울특별시 종로구 창경궁로 112-16
# 5    서울용산경찰서                 서울특별시 용산구 원효로89길 24
# 6    서울성북경찰서                   서울특별시 성북구 보문로 170
# 7   서울동대문경찰서              서울특별시 동대문구 약령시로 21길 29
# 8    서울마포경찰서                  서울특별시 마포구 마포대로 183
# 9   서울영등포경찰서                 서울특별시 영등포구 국회대로 608
# 10   서울성동경찰서                  서울특별시 성동구 왕십리광장로 9
# 11   서울동작경찰서                  서울특별시 동작구 노량진로 148
# 12   서울광진경찰서  서울특별시 광진구 광나루로 447 광진소방서 임시청사 (능동)
# 13   서울서부경찰서                  서울특별시 은평구 은평로9길 15
# 14   서울강북경찰서                  서울특별시 강북구 오패산로 406
# 15   서울금천경찰서                서울특별시 관악구 남부순환로 1435
# 16   서울중랑경찰서                  서울특별시 중랑구 중랑역로 137
# 17   서울강남경찰서              서울특별시 강남구 테헤란로 114길 11
# 18   서울관악경찰서                  서울특별시 관악구 관악로5길 33
# 19   서울강서경찰서                    서울특별시 양천구 화곡로 73
# 20   서울강동경찰서                    서울특별시 강동구 성내로 33
# 21   서울종암경찰서                   서울특별시 성북구 종암로 135
# 22   서울구로경찰서                  서울특별시 구로구 가마산로 235
# 23   서울서초경찰서                  서울특별시 서초구 반포대로 179
# 24   서울양천경찰서                   서울특별시 양천구 목동동로 99
# 25   서울송파경찰서                   서울특별시 송파구 중대로 221
# 26   서울노원경찰서                   서울특별시 노원구 노원로 283
# 27   서울방배경찰서                   서울특별시 서초구 방배천로 54
# 28   서울도봉경찰서                   서울특별시 도봉구 노해로 403
# 29   서울수서경찰서                   서울특별시 강남구 개포로 617
# 30   서울은평경찰서                   서울특별시 은평구 연서로 365

# %%
df1.to_csv('서울시경찰서.csv', index=False)

# %%
df = pd.read_csv('서울시경찰서.csv', encoding='utf-8')
df          # 주소 변경후 확인
# Out:
#         경찰서명                                  주소
# 0    서울중부경찰서                     서울특별시 중구 수표로 27
# 1    서울종로경찰서                    서울특별시 종로구 율곡로 46
# 2   서울남대문경찰서                   서울특별시 중구 한강대로 410
# 3   서울서대문경찰서                  서울특별시 서대문구 통일로 113
# 4    서울혜화경찰서               서울특별시 종로구 창경궁로 112-16
# 5    서울용산경찰서                 서울특별시 용산구 원효로89길 24
# 6    서울성북경찰서                   서울특별시 성북구 보문로 170
# 7   서울동대문경찰서              서울특별시 동대문구 약령시로 21길 29
# 8    서울마포경찰서                  서울특별시 마포구 마포대로 183
# 9   서울영등포경찰서                 서울특별시 영등포구 국회대로 608
# 10   서울성동경찰서                  서울특별시 성동구 왕십리광장로 9
# 11   서울동작경찰서                  서울특별시 동작구 노량진로 148
# 12   서울광진경찰서  서울특별시 광진구 광나루로 447 광진소방서 임시청사 (능동)
# 13   서울서부경찰서                   서울특별시 은평구 서오릉로 58
# 14   서울강북경찰서                  서울특별시 강북구 오패산로 406
# 15   서울금천경찰서                서울특별시 관악구 남부순환로 1435
# 16   서울중랑경찰서                  서울특별시 중랑구 중랑역로 137
# 17   서울강남경찰서              서울특별시 강남구 테헤란로 114길 11
# 18   서울관악경찰서                  서울특별시 관악구 관악로5길 33
# 19   서울강서경찰서                    서울특별시 양천구 화곡로 73
# 20   서울강동경찰서                서울특별시 강동구 양재대로96길 35
# 21   서울종암경찰서                   서울특별시 성북구 종암로 135
# 22   서울구로경찰서                  서울특별시 구로구 가마산로 235
# 23   서울서초경찰서                  서울특별시 서초구 반포대로 179
# 24   서울양천경찰서                   서울특별시 양천구 목동동로 99
# 25   서울송파경찰서                   서울특별시 송파구 중대로 221
# 26   서울노원경찰서                   서울특별시 노원구 노원로 283
# 27   서울방배경찰서                   서울특별시 서초구 방배천로 54
# 28   서울도봉경찰서                   서울특별시 도봉구 노해로 403
# 29   서울수서경찰서                   서울특별시 강남구 개포로 617
# 30   서울은평경찰서                   서울특별시 은평구 연서로 365

# %%
with open('../05.Crawling/kakaoapikey.txt') as file:
    kakao_key = file.read()
len(kakao_key)
# Out:
# 32

# %%
local_url = 'https://dapi.kakao.com/v2/local/search/address.json'
addr = '서울특별시 중구 수표로 27'
url = f'{local_url}?query={quote(addr)}'
url
# Out:
# 'https://dapi.kakao.com/v2/local/search/address.json?query=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EC%A4%91%EA%B5%AC%20%EC%88%98%ED%91%9C%EB%A1%9C%2027'

# %%
header = {'Authorization': f'KakaoAK {kakao_key}'}

# %%
result = requests.get(url, headers=header).json()
result
# Out:
# {'documents': [{'address': {'address_name': '서울 중구 저동2가 62-1',
#     'b_code': '1114016100',
#     'h_code': '1114060500',
#     'main_address_no': '62',
#     'mountain_yn': 'N',
#     'region_1depth_name': '서울',
#     'region_2depth_name': '중구',
#     'region_3depth_h_name': '을지로동',
#     'region_3depth_name': '저동2가',
#     'sub_address_no': '1',
#     'x': '126.990020639754',
#     'y': '37.5636321301236'},
#    'address_name': '서울 중구 수표로 27',
#    'address_type': 'ROAD_ADDR',
#    'road_address': {'address_name': '서울 중구 수표로 27',
#     'building_name': '서울중부경찰서',
#     'main_building_no': '27',
#     'region_1depth_name': '서울',
#     'region_2depth_name': '중구',
#     'region_3depth_name': '저동2가',
#     'road_name': '수표로',
#     'sub_building_no': '',
#     'underground_yn': 'N',
#     'x': '126.990020639754',
#     'y': '37.5636321301236',
#     'zone_no': '04552'},
#    'x': '126.990020639754',
#    'y': '37.5636321301236'}],
#  'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}

# %%
lng = float(result['documents'][0]['x'])
lat = float(result['documents'][0]['y'])

# %%
lng, lat
# Out:
# (126.990020639754, 37.5636321301236)

# %%
lng_list, lat_list = [],[]
for i in df.index:
    url = f'{local_url}?query={quote(df.주소[i])}'
    result = requests.get(url, headers=header).json()
    lng_list.append(float(result['documents'][0]['x']))
    lat_list.append(float(result['documents'][0]['y']))

# %%
df['위도']= lat_list
df['경도']= lng_list
df
# Out:
#         경찰서명                                  주소         위도          경도
# 0    서울중부경찰서                     서울특별시 중구 수표로 27  37.563632  126.990021
# 1    서울종로경찰서                    서울특별시 종로구 율곡로 46  37.575876  126.984551
# 2   서울남대문경찰서                   서울특별시 중구 한강대로 410  37.554811  126.973549
# 3   서울서대문경찰서                  서울특별시 서대문구 통일로 113  37.565085  126.967074
# 4    서울혜화경찰서               서울특별시 종로구 창경궁로 112-16  37.571768  126.999273
# 5    서울용산경찰서                 서울특별시 용산구 원효로89길 24  37.541538  126.967648
# 6    서울성북경찰서                   서울특별시 성북구 보문로 170  37.589980  127.016215
# 7   서울동대문경찰서              서울특별시 동대문구 약령시로 21길 29  37.585158  127.045794
# 8    서울마포경찰서                  서울특별시 마포구 마포대로 183  37.550830  126.954018
# 9   서울영등포경찰서                 서울특별시 영등포구 국회대로 608  37.525956  126.901006
# 10   서울성동경찰서                  서울특별시 성동구 왕십리광장로 9  37.562003  127.036199
# 11   서울동작경찰서                  서울특별시 동작구 노량진로 148  37.512796  126.942549
# 12   서울광진경찰서  서울특별시 광진구 광나루로 447 광진소방서 임시청사 (능동)  37.545698  127.079137
# 13   서울서부경찰서                   서울특별시 은평구 서오릉로 58  37.605846  126.923591
# 14   서울강북경찰서                  서울특별시 강북구 오패산로 406  37.637170  127.027042
# 15   서울금천경찰서                서울특별시 관악구 남부순환로 1435  37.481410  126.909994
# 16   서울중랑경찰서                  서울특별시 중랑구 중랑역로 137  37.605972  127.076472
# 17   서울강남경찰서              서울특별시 강남구 테헤란로 114길 11  37.509367  127.067100
# 18   서울관악경찰서                  서울특별시 관악구 관악로5길 33  37.474234  126.951870
# 19   서울강서경찰서                    서울특별시 양천구 화곡로 73  37.539801  126.829982
# 20   서울강동경찰서                서울특별시 강동구 양재대로96길 35  37.529451  127.139189
# 21   서울종암경찰서                   서울특별시 성북구 종암로 135  37.602348  127.032209
# 22   서울구로경찰서                  서울특별시 구로구 가마산로 235  37.494532  126.887015
# 23   서울서초경찰서                  서울특별시 서초구 반포대로 179  37.495743  127.005161
# 24   서울양천경찰서                   서울특별시 양천구 목동동로 99  37.516676  126.865594
# 25   서울송파경찰서                   서울특별시 송파구 중대로 221  37.501849  127.127601
# 26   서울노원경찰서                   서울특별시 노원구 노원로 283  37.641975  127.070799
# 27   서울방배경찰서                   서울특별시 서초구 방배천로 54  37.481773  126.982785
# 28   서울도봉경찰서                   서울특별시 도봉구 노해로 403  37.653512  127.052576
# 29   서울수서경찰서                   서울특별시 강남구 개포로 617  37.493549  127.077144
# 30   서울은평경찰서                   서울특별시 은평구 연서로 365  37.627814  126.929156

# %%
import folium
from folium.features import DivIcon
from folium.features import CustomIcon

# %%
map = folium.Map(location=[df.위도.mean(),df.경도.mean()], zoom_start=11)
for i in df.index:
    folium.Marker(
        location=[df.위도[i],df.경도[i]],
        popup=folium.Popup(df.주소[i], max_width=200),
        tooltip=df.경찰서명[i],
        icon = folium.Icon(color='red', icon='glyphicon glyphicon-volume-off')
    ).add_to(map)
title_html = '<h3 align="center" style="font-size:20px">서울소재 경찰서 위치</h3>' 
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2418b559bef24096b45cabb478b1e212%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%3Ch3%20align%3D%22center%22%20style%3D%22font-size%3A20px%22%3E%EC%84%9C%EC%9A%B8%EC%86%8C%EC%9E%AC%20%EA%B2%BD%EC%B0%B0%EC%84%9C%20%EC%9C%84%EC%B9%98%3C/h3%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2418b559bef24096b45cabb478b1e212%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2418b559bef24096b45cabb478b1e212%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2418b559bef24096b45cabb478b1e212%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20 ...
